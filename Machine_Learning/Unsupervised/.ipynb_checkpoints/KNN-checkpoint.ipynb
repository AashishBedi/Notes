# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("C:/Users/91798/Desktop/DATA_ENGINEERING/Machine_Learning/Unsupervised/data.csv", delimiter=',', encoding='ISO-8859-1')

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data.shape
# Out:
# (541909, 8)

# %%
##Data Preprocessing

# %%
data.dropna(inplace=True)

# %%
data = data[data['Quantity'] > 0]
data[data['UnitPrice']<0].shape[0]
# Out:
# 0

# %%
data.drop(data[data['Quantity'] < 0].index, inplace=True)

# %%
##Feature Engineering

# %%
data['Sales'] = data['Quantity'] * data['UnitPrice']
new_data = data.groupby('CustomerID')['Sales'].sum().reset_index()
new_data
# Out:
#       CustomerID     Sales
# 0        12346.0  77183.60
# 1        12347.0   4310.00
# 2        12348.0   1797.24
# 3        12349.0   1757.55
# 4        12350.0    334.40
# ...          ...       ...
# 4334     18280.0    180.60
# 4335     18281.0     80.82
# 4336     18282.0    178.05
# 4337     18283.0   2094.88
# 4338     18287.0   1837.28
#
# [4339 rows x 2 columns]

# %%
#Number of Transactions
num_trans = data.groupby('CustomerID')['InvoiceNo'].count().reset_index()
num_trans
# Out:
#       CustomerID  InvoiceNo
# 0        12346.0          1
# 1        12347.0        182
# 2        12348.0         31
# 3        12349.0         73
# 4        12350.0         17
# ...          ...        ...
# 4334     18280.0         10
# 4335     18281.0          7
# 4336     18282.0         12
# 4337     18283.0        756
# 4338     18287.0         70
#
# [4339 rows x 2 columns]

# %%
#Calculating last transaction
#Converting 'InvoiceDate' to DateTime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
#Calculating 'Last Transaction' Days:
data['Last Transaction'] = (data['InvoiceDate'].max() - data['InvoiceDate']).dt.days
#Grouping by 'CustomerID' and 'Country' and Calculating Maximum 'Last Transaction'
lt = data.groupby(['CustomerID', 'Country'])['Last Transaction'].max().reset_index()
#Merging with Number of Transactions
merge_table = pd.merge(lt, num_trans, how='inner', on='CustomerID')
new_df = pd.merge(merge_table, new_data, how='inner', on='CustomerID')
print(lt)
print(new_df)
# Out:
#       CustomerID         Country  Last Transaction
# 0        12346.0  United Kingdom               325
# 1        12347.0         Iceland               366
# 2        12348.0         Finland               357
# 3        12349.0           Italy                18
# 4        12350.0          Norway               309
# ...          ...             ...               ...
# 4342     18280.0  United Kingdom               277
# 4343     18281.0  United Kingdom               180
# 4344     18282.0  United Kingdom               125
# 4345     18283.0  United Kingdom               336
# 4346     18287.0  United Kingdom               201
#
# [4347 rows x 3 columns]
#       CustomerID         Country  Last Transaction  InvoiceNo     Sales
# 0        12346.0  United Kingdom               325          1  77183.60
# 1        12347.0         Iceland               366        182   4310.00
# 2        12348.0         Finland               357         31   1797.24
# 3        12349.0           Italy                18         73   1757.55
# 4        12350.0          Norway               309         17    334.40
# ...          ...             ...               ...        ...       ...
# 4342     18280.0  United Kingdom               277         10    180.60
# 4343     18281.0  United Kingdom               180          7     80.82
# 4344     18282.0  United Kingdom               125         12    178.05
# 4345     18283.0  United Kingdom               336        756   2094.88
# 4346     18287.0  United Kingdom               201         70   1837.28
#
# [4347 rows x 5 columns]

# %%
#Removing Outliers
plt.figure(figsize=(20, 10))
sns.boxplot(data=new_df[['InvoiceNo', 'Last Transaction', 'Sales']])
plt.show()

IQR = new_df['Sales'].quantile(0.75) - new_df['Sales'].quantile(0.25)
lower_limit = new_df['Sales'].quantile(0.25) - 1.5 * IQR
upper_limit = new_df['Sales'].quantile(0.75) + 1.5 * IQR
new_df_iqr = new_df[(new_df['Sales'] < upper_limit) & (new_df['Sales'] > lower_limit)]

plt.figure(figsize=(20, 10))
sns.boxplot(data=new_df_iqr[['InvoiceNo', 'Last Transaction', 'Sales']])
plt.show()

new_df_iqr.reset_index(drop=True, inplace=True)

# %% [markdown]
# Visualization of Correlation Matrix using Heatmap

# %%
#1. Normalization of Given Dataset using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler
new2_df= new_df_iqr[['Last Transaction','InvoiceNo','Sales']]
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(new2_df)
scaled_df = pd.DataFrame(scaled_df)
scaled_df.columns = ['Last Transaction','InvoiceNo','Sales']
scaled_df['Country'] = new_df_iqr['Country']
scaled_df
# Out:
#       Last Transaction  InvoiceNo     Sales         Country
# 0             0.957105   0.030960  0.484200         Finland
# 1             0.048257   0.074303  0.473507           Italy
# 2             0.828418   0.016512  0.090092          Norway
# 3             0.793566   0.086687  0.675160          Norway
# 4             0.544236   0.003096  0.023978         Bahrain
# ...                ...        ...       ...             ...
# 3918          0.742627   0.009288  0.048656  United Kingdom
# 3919          0.482574   0.006192  0.021774  United Kingdom
# 3920          0.335121   0.011352  0.047969  United Kingdom
# 3921          0.900804   0.779154  0.564388  United Kingdom
# 3922          0.538874   0.071207  0.494988  United Kingdom
#
# [3923 rows x 4 columns]

# %%
# !pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\91798\anaconda3\lib\site-packages (from yellowbrick) (3.9.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\91798\anaconda3\lib\site-packages (from yellowbrick) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\91798\anaconda3\lib\site-packages (from yellowbrick) (1.5.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\91798\anaconda3\lib\site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\91798\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91798\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\91798\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\91798\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\91798\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
#2. K-Means Clustering - Plotting the Graph using Elbow Method

df_k=scaled_df.drop(columns=['Country'],axis=1)
# Elbow Method for K means
# Import ElbowVisualizer
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(model, k=(1,11), timings= False)
visualizer.fit(df_k)        # Fit data to visualizer
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# Model Evaluation

# %%
'''from sklearn.metrics import silhouette_samples, silhouette_score
score = silhouette_score(df_k, km.labels_, metric='euclidean')
print(score)

from sklearn.cluster import AgglomerativeClustering
hierarchial = AgglomerativeClustering(n_clusters=3)
y_predicted_hierarchial = hierarchial.fit_predict(df_k)
df_k['clusters_hierarchial']= y_predicted_hierarchial
df_k.head(30)'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 from sklearn.metrics import silhouette_samples, silhouette_score
# ----> 2 score = silhouette_score(df_k, km.labels_, metric='euclidean')
#       3 print(score)
#       5 from sklearn.cluster import AgglomerativeClustering
#
# NameError: name 'km' is not defined

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# Fit KMeans with the optimal number of clusters (e.g., 3)
km = KMeans(n_clusters=3, random_state=42)
km.fit(df_k)

# Calculate silhouette score
score = silhouette_score(df_k, km.labels_, metric='euclidean')
print("Silhouette Score (KMeans):", score)

# Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering

hierarchial = AgglomerativeClustering(n_clusters=3)
y_predicted_hierarchial = hierarchial.fit_predict(df_k)

df_k['clusters_hierarchial'] = y_predicted_hierarchial
df_k.head(30)
# Out:
# Silhouette Score (KMeans): 0.48538312715888937
#     Last Transaction  InvoiceNo     Sales  clusters_hierarchial
# 0           0.957105   0.030960  0.484200                     2
# 1           0.048257   0.074303  0.473507                     0
# 2           0.828418   0.016512  0.090092                     1
# 3           0.793566   0.086687  0.675160                     2
# 4           0.544236   0.003096  0.023978                     0
# 5           0.619303   0.058824  0.290805                     0
# 6           0.571046   0.012384  0.123768                     0
# 7           0.871314   0.059856  0.757436                     2
# 8           0.402145   0.018576  0.314691                     0
# 9           0.536193   0.132095  0.717194                     0
# 10          0.766756   0.009288  0.051162                     1
# 11          0.646113   0.022704  0.148716                     0
# 12          0.297587   0.086687  0.353767                     0
# 13          0.777480   0.021672  0.172796                     1
# 14          0.008043   0.010320  0.045504                     0
# 15          0.957105   0.171311  0.955256                     2
# 16          0.962466   0.171311  0.955256                     2
# 17          0.158177   0.063983  0.508641                     0
# 18          0.793566   0.052632  0.349709                     1
# 19          0.831099   0.013416  0.098228                     1
# 20          0.064343   0.033024  0.200155                     0
# 21          0.260054   0.016512  0.123257                     0
# 22          0.949062   0.078431  0.438637                     2
# 23          0.453083   0.040248  0.229605                     0
# 24          0.495979   0.106295  0.734100                     0
# 25          0.319035   0.088751  0.497151                     0
# 26          0.941019   0.101135  0.498565                     2
# 27          0.324397   0.026832  0.157679                     0
# 28          0.981233   0.009288  0.108277                     1
# 29          0.873995   0.102167  0.749147                     2

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
score = silhouette_score(df_k, km.labels_, metric='euclidean')
print(score)
# Out:
# 0.45149454009243156

# %%
#Agglomerative Clustering
from sklearn.cluster import AgglomerativeClustering
import numpy as np

X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])


clustering = AgglomerativeClustering(n_clusters=2).fit(X)

print(clustering.labels_)
# Out:
# [1 1 1 0 0 0]

# %%
#Divisive Clustering
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt


X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

Z = linkage(X, 'ward') # Ward Distance

dendrogram(Z) #plotting the dendogram

plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.2,min_samples = 4 )
y_predicted_dbscan = dbscan.fit_predict(df_k)
df_k['clusters_dbscan'] = y_predicted_dbscan
df_k
# Out:
#       Last Transaction  InvoiceNo     Sales  clusters_hierarchial  \
# 0             0.957105   0.030960  0.484200                     2
# 1             0.048257   0.074303  0.473507                     0
# 2             0.828418   0.016512  0.090092                     1
# 3             0.793566   0.086687  0.675160                     2
# 4             0.544236   0.003096  0.023978                     0
# ...                ...        ...       ...                   ...
# 3918          0.742627   0.009288  0.048656                     1
# 3919          0.482574   0.006192  0.021774                     0
# 3920          0.335121   0.011352  0.047969                     0
# 3921          0.900804   0.779154  0.564388                     2
# 3922          0.538874   0.071207  0.494988                     0
#
#       clusters_dbscan
# 0                   0
# 1                   1
# 2                   2
# 3                   0
# 4                   1
# ...               ...
# 3918                2
# 3919                1
# 3920                1
# 3921                0
# 3922                1
#
# [3923 rows x 5 columns]

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
score = silhouette_score(df_k, dbscan.labels_, metric='euclidean')
print(score)
# Out:
# 0.8172746601639875
