# %%
#If there are special symbols in csv file
'''
data = open('business2023.csv', encoding='utf-8')
'''

# %%
pwd
# Out:
# 'C:\\Users\\91798\\Desktop\\ROADMAP\\DATA ENGINEERING\\1_PYTHON'

# %%
import csv

# %%
#Open  file
data = open('business2023.csv')

# %%
#csv.reader
csv_data = csv.reader(data)

# %%
#reformat it into a python object list of lists
data_lines = list(csv_data)

# %%
data_lines
# Out:
# [['description',
#   'industry',
#   'level',
#   'size',
#   'line_code',
#   'value',
#   'status',
#   'Unit',
#   'Footnotes'],
#  ['Total number of businesses',
#   'total',
#   '0',
#   '6–19 employees',
#   '',
#   '35562',
#   '',
#   'Number of businesses',
#   '1 and 2 and 3 and 4 and 6'],
#  ['Total number of businesses',
#   'total',
#   '0',
#   '20–49 employees',
#   '',
#   '8796',
#   '',
#   'Number of businesses',
#   '1 and 2 and 3 and 4 and 6'],
#  ['Total number of businesses',
#   'total',
#   '0',
#   '50–99 employees',
#   '',
#   '2529',
#   '',
#   'Number of businesses',
#   '1 and 2 and 3 and 4 and 6'],
#  ['Total number of businesses',
#   'total',
#   '0',
#   '100+ employees',
#   '',
#   '2100',
#   '',
#   'Number of businesses',
#   '1 and 2 and 3 and 4 and 6'],
#  ['Total number of businesses',
#   'Agriculture, forestry, & fishing',
#   '1',
#   'total',
#   '',
#   '3756',
#   '',
#   'Number of businesses',
#   '1 and 2 and 3 and 6'],
# ...

# %%
data_lines[0]
# Out:
# ['description',
#  'industry',
#  'level',
#  'size',
#  'line_code',
#  'value',
#  'status',
#  'Unit',
#  'Footnotes']

# %%
len(data_lines)
# Out:
# 11986

# %%
for line in data_lines[:5]:
    print(line)
# Out:
# ['description', 'industry', 'level', 'size', 'line_code', 'value', 'status', 'Unit', 'Footnotes']
# ['Total number of businesses', 'total', '0', '6–19 employees', '', '35562', '', 'Number of businesses', '1 and 2 and 3 and 4 and 6']
# ['Total number of businesses', 'total', '0', '20–49 employees', '', '8796', '', 'Number of businesses', '1 and 2 and 3 and 4 and 6']
# ['Total number of businesses', 'total', '0', '50–99 employees', '', '2529', '', 'Number of businesses', '1 and 2 and 3 and 4 and 6']
# ['Total number of businesses', 'total', '0', '100+ employees', '', '2100', '', 'Number of businesses', '1 and 2 and 3 and 4 and 6']

# %%
data_lines[10]
# Out:
# ['Total number of businesses',
#  'Mining',
#  '1',
#  'total',
#  '',
#  '120',
#  '',
#  'Number of businesses',
#  '1 and 2 and 3 and 5 and 6']

# %%
data_lines[10][3]
# Out:
# 'total'

# %%
all_ = []
for line in data_lines[1:10]:
    all_.append(line[3])

# %%
all_
# Out:
# ['6–19 employees',
#  '20–49 employees',
#  '50–99 employees',
#  '100+ employees',
#  'total',
#  'total',
#  'total',
#  'total',
#  'total']
